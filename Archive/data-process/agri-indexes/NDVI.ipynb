# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: folium in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from -r requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: geojsonio in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from -r requirements.txt (line 2)) (0.0.3)
# Requirement already satisfied: geopandas in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from -r requirements.txt (line 3)) (0.5.1)
# Collecting geopy (from -r requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/80/93/d384479da0ead712bdaf697a8399c13a9a89bd856ada5a27d462fb45e47b/geopy-1.20.0-py2.py3-none-any.whl (100kB)
#      |████████████████████████████████| 102kB 2.0MB/s ta 0:00:011
# Requirement already satisfied: Pillow in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from -r requirements.txt (line 5)) (6.1.0)
# Requirement already satisfied: rasterio in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from -r requirements.txt (line 6)) (1.0.27)
# Requirement already satisfied: sentinelsat in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from -r requirements.txt (line 7)) (0.13)
# Requirement already satisfied: shapely in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from -r requirements.txt (line 8)) (1.6.4.post2)
# Requirement already satisfied: branca>=0.3.0 in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from folium->-r requirements.txt (line 1)) (0.3.1)
# Requirement already satisfied: requests in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from folium->-r requirements.txt (line 1)) (2.22.0)
# Requirement already satisfied: jinja2>=2.9 in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from folium->-r requirements.txt (line 1)) (2.10.1)
# Requirement already satisfied: numpy in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from folium->-r requirements.txt (line 1)) (1.16.4)
# Requirement already satisfied: github3.py in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from geojsonio->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: six in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from geojsonio->-r requirements.txt (line 2)) (1.12.0)
# Requirement already satisfied: pyproj in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from geopandas->-r requirements.txt (line 3)) (2.3.1)
# Requirement already satisfied: fiona in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from geopandas->-r requirements.txt (line 3)) (1.8.6)
# Requirement already satisfied: pandas in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from geopandas->-r requirements.txt (line 3)) (0.25.0)
# Collecting geographiclib<2,>=1.49 (from geopy->-r requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/5b/ac/4f348828091490d77899bc74e92238e2b55c59392f21948f296e94e50e2b/geographiclib-1.49.tar.gz
# Requirement already satisfied: click-plugins in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from rasterio->-r requirements.txt (line 6)) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from rasterio->-r requirements.txt (line 6)) (0.5.0)
# Requirement already satisfied: attrs in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from rasterio->-r requirements.txt (line 6)) (19.1.0)
# Requirement already satisfied: snuggs>=1.4.1 in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from rasterio->-r requirements.txt (line 6)) (1.4.6)
# Requirement already satisfied: click<8,>=4.0 in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from rasterio->-r requirements.txt (line 6)) (7.0)
# Requirement already satisfied: affine in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from rasterio->-r requirements.txt (line 6)) (2.3.0)
# Requirement already satisfied: html2text in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from sentinelsat->-r requirements.txt (line 7)) (2019.8.11)
# Requirement already satisfied: geojson>=2 in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from sentinelsat->-r requirements.txt (line 7)) (2.5.0)
# Requirement already satisfied: geomet in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from sentinelsat->-r requirements.txt (line 7)) (0.2.1)
# Requirement already satisfied: tqdm in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from sentinelsat->-r requirements.txt (line 7)) (4.35.0)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from requests->folium->-r requirements.txt (line 1)) (2019.6.16)
# Requirement already satisfied: idna<2.9,>=2.5 in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from requests->folium->-r requirements.txt (line 1)) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from requests->folium->-r requirements.txt (line 1)) (1.25.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from requests->folium->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from jinja2>=2.9->folium->-r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.6.0 in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from github3.py->geojsonio->-r requirements.txt (line 2)) (2.8.0)
# Requirement already satisfied: jwcrypto>=0.5.0 in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from github3.py->geojsonio->-r requirements.txt (line 2)) (0.6.0)
# Requirement already satisfied: uritemplate>=3.0.0 in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from github3.py->geojsonio->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: munch in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from fiona->geopandas->-r requirements.txt (line 3)) (2.3.2)
# Requirement already satisfied: pytz>=2017.2 in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from pandas->geopandas->-r requirements.txt (line 3)) (2019.2)
# Requirement already satisfied: pyparsing>=2.1.6 in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from snuggs>=1.4.1->rasterio->-r requirements.txt (line 6)) (2.4.2)
# Requirement already satisfied: cryptography>=1.5 in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from jwcrypto>=0.5.0->github3.py->geojsonio->-r requirements.txt (line 2)) (2.7)
# Requirement already satisfied: asn1crypto>=0.21.0 in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from cryptography>=1.5->jwcrypto>=0.5.0->github3.py->geojsonio->-r requirements.txt (line 2)) (0.24.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from cryptography>=1.5->jwcrypto>=0.5.0->github3.py->geojsonio->-r requirements.txt (line 2)) (1.12.3)
# Requirement already satisfied: pycparser in /anaconda3/envs/mlsa/lib/python3.7/site-packages (from cffi!=1.11.3,>=1.8->cryptography>=1.5->jwcrypto>=0.5.0->github3.py->geojsonio->-r requirements.txt (line 2)) (2.19)
# Building wheels for collected packages: geographiclib
#   Building wheel for geographiclib (setup.py) ... done
#   Stored in directory: /Users/yuanwenliang/Library/Caches/pip/wheels/99/45/d1/14954797e2a976083182c2e7da9b4e924509e59b6e5c661061
# Successfully built geographiclib
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.49 geopy-1.20.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Vegetation Index
# ### *Using NDVI (Normalized Difference Vegetation Index)
#
# To calculate the NDVI, we need Red band and Near-Infrared Band (NIR). Different satellite images assign different numbers for these bands. Sentinel Images have red in 4th band and NIR in the 8th band. The formula for NDVI calculation is:
#
# $$NDVI = \frac{nir - red}{nir + red} $$
#
#
# We use `rasterio` here to calculate and visualize ndvi. Rasterio document: https://rasterio.readthedocs.io/en/stable/quickstart.html

# %%
import rasterio as rio
from rasterio import plot
import numpy as np
from PIL import Image, ImageDraw
import glob
import os
import matplotlib.pyplot as plt
from matplotlib import colors



# The initial release contains only one tile, so lets hardcode its location
# here.  When you have more tiles, you can update this
TILE_X = 7680
TILE_Y = 10240

# The expected value of a Pixel in a mask file indicating that the pixel is
# within that region.  Tuple value, (Red, Green, Blue, Alpha)
IS_IN_MASK_PIXEL_VALUE = (0, 0, 0, 255)

# Tile width / height in pixels

TILE_WIDTH_PX = 512
TILE_HEIGHT_PX = 512

def get_cropped_image_paths(tile_x, tile_y, band, date):
    path = f"../data/sentinel-2a-tile-{tile_x}x-{tile_y}y/cropped/cropped-{tile_x}-{tile_y}-{band}-{date}.png"
    #path = glob.glob(path)
    #path = path[0] # get the first date 
    return path 

def get_timeseries_image_paths(tile_x, tile_y, band, date):
    path = f"../data/sentinel-2a-tile-{tile_x}x-{tile_y}y/timeseries/{tile_x}-{tile_y}-{band}-{date}.png"
    #path = glob.glob(path)
    #path = path[0] # get the first date 
    return path 

def normalize(array):
    array_min, array_max = array.min(), array.max()
    return ((array - array_min)/(array_max - array_min))

def get_band(tile_x, tile_y, date, band, cropped = False):
    if cropped == True:
        path = get_cropped_image_paths(tile_x, tile_y, band, date)
    else:
        path = get_timeseries_image_paths(tile_x, tile_y, band, date)
    
    b = rio.open(path)
    read = normalize(b.read(1))
    
    get_band = dict()
    get_band['read'] = read; get_band['b'] = b

    return get_band

# %%
def NDVI(tile_x, tile_y, date, img = 'NDVI'):
    get_red = get_band(tile_x, tile_y, date, band='B04')
    red = get_red['read']
    b4 = get_red['b']
    
    get_nir = get_band(tile_x, tile_y, date, band='B08')
    nir = get_nir['read']
    b8 = get_nir['b']
    
    get_green = get_band(tile_x, tile_y, date, band='B03')
    b3 = get_green['b']; green = get_green['read']
   
    ndvi = np.where((nir+red)==0., 0, (nir-red)/(nir+red))

    # Stack bands
    ndvi = np.dstack((nir, ndvi, green))

    # View the color composite
    plt.imshow(ndvi)
    plt.savefig(f'../Output/ndvimap-{tile_x}-{tile_y}-{date}.png')

    return ndvi

# %%
ndvi = NDVI(TILE_X, TILE_Y,'2016-12-22')
# Out:
# /anaconda3/envs/mlsa/lib/python3.7/site-packages/rasterio/__init__.py:216: NotGeoreferencedWarning: Dataset has no geotransform set. The identity matrix may be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# At least three types of vegetation can be discriminated in this colour composite image: green, bright yellow and golden yellow areas. The green areas consist of dense trees with closed canopy. The bright yellow areas are covered with shrubs or less dense trees. The golden yellow areas are covered with green fields. The non vegetated areas appear in dark blue and magenta.

# %% [markdown]
# These ones don't work.
#
#     #export false color image
#     meta = dict(driver='Gtiff',
#             width=b2.width, height=b2.height,
#             count=3, crs=b2.crs,
#             transform=b2.transform,
#             dtype='float64')
#
#     layer_list = ['nir','red', 'green']
#
#     with rio.open(f'./Output/fci-{tile_x}-{tile_y}-{date}.png','w', **meta) as dst:
#         for index, layer in enumerate(layer_list, start=1):
#             dst.write(layer,int(index))
#
#     # show FCI, can remove
#     FCI = rio.open(f'./Output/fci-{tile_x}-{tile_y}-{date}.png', count=3)
#     plot.show(FCI)
#
#
#
#
#
#
#
#
#     ndviImage = rio.open(f'./Output/ndvimap-{tile_x}-{tile_y}-{date}.png',
#                          'w',driver='Gtiff',
#                           width=b4.width,
#                           height = b4.height,
#                           count=1, crs=b4.crs,
#                           transform=b4.transform,
#                           dtype='float64')
#
#     ndviImage.write(ndvi,1)
#     ndviImage.close()
#
#     #show ndvi, can remove
#     ndviImg = rio.open(f'./Output/ndvimap-{tile_x}-{tile_y}-{date}.png')
#     plot.show(ndviImg)
#
#
#
#
#
#
#
#
#
#     #export false color image
#     TCI = rio.open(f'./Output/tci-{tile_x}-{tile_y}-{date}.png',
#                                'w', driver='Gtiff',
#                                width=b4.width, height=b4.height,
#                                count=3, crs=b4.crs,
#                                transform=b4.transform,
#                                dtype='float64')
#     TCI.write(blue,1)
#     TCI.write(green,2)
#     TCI.write(red,3)
#     TCI.close()
#
#     # show TCI, can remove
#     TCI = rio.open(f'./Output/tci-{tile_x}-{tile_y}-{date}.png', count=3)
#     plot.show(TCI)
